# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import glob
import os
os.environ.get("UOFS_DIR")

# %%
UOFS_DIR = open("/home/cusp/clm633/uofs_dir").read().strip()

# %%
dudes = sorted([f for f in glob.glob(UOFS_DIR+"/2017-09-24_night/*d6*") if "png" in f], 
               key=lambda x: int(x.split("_")[-1].split(".")[0]))
len(dudes)
# Out:
# 3133

# %%
import weather

imf = dudes[100]
plt.imshow(np.rot90(plt.imread(imf), 3 if 'd6' in imf else 1))
plt.plot([weather.x1_d6, weather.x2_d6], [weather.y1_d6, weather.y2_d6], color='red')

# %%
x1_d6 = 200
x2_d6 = 1000
y1_d6 = 200
y2_d6 = 1000

im = plt.imread(imf)
plt.imshow(im)
plt.plot([x1_d6, x2_d6], [y1_d6, y2_d6], color='red')

# %%
plt.imshow(im[y1_d6:y2_d6, x1_d6:x2_d6])

# %%
# format: x1, x2, y1, y2
squares = [(1080, 1500, 2450, 2700),
           (3050, 3180, 1020, 1250),
           (3480, 3610, 820, 1010),
           (1500 + 600, 1500 + 900, 650, 800),
           (1500 + 600 + 130, 1500 + 600 + 140, 250, 310),
           (2440, 2480, 3720, 3750),
           (2470, 2490, 20, 40),
           (2000 + 940, 2970, 300, 330),
           (2000 + 680, 2000 + 760, 1500 + 300, 1500 + 380),
           (2000 + 370 + 10, 2000 + 410, 1500 + 400, 1500 + 450)]
plt.imshow(im)
for x1, x2, y1, y2 in squares:
    plt.plot([x1, x1], [y1, y2], color='red')
    plt.plot([x2, x2], [y1, y2], color='red')
    plt.plot([x1, x2], [y1, y1], color='red')
    plt.plot([x1, x2], [y2, y2], color='red')

# %%
esb = squares[-5]
ax = plt.imshow(im[esb[2]:esb[3], esb[0]:esb[1]])

# %%
df = pd.read_csv("weather_results/2017-09-01.csv0")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-163-82875b82b396> in <module>()
# ----> 1 df = pd.read_csv("weather_results/2017-09-01.csv0")
#
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
squares = [(1080, 1500, 2450, 2700),]
six = squares[0]
plt.imshow(im[six[2]:six[3],six[0]:six[1]])

# %% [markdown]
# ## Now, d9

# %%
dudes_d9 = sorted([f for f in glob.glob(UOFS_DIR+"/2017-09-28_night/*d9*") if "png" in f], 
               key=lambda x: int(x.split("_")[-1].split(".")[0]))
len(dudes_d9)
# Out:
# 3149

# %%
dudes_d9[0]
# Out:
# '/uofs15tb_gpfs/data//2017-09-28_night/0_d9_1506646816.png'

# %%
imf = dudes_d9[0]
plt.imshow(np.rot90(plt.imread(imf), 3 if 'd6' in imf else 1))
#plt.plot([weather.x1_d6, weather.x2_d6], [weather.y1_d6, weather.y2_d6], color='red')
